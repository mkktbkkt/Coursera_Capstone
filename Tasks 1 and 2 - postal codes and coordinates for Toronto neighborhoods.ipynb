# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
from requests import get
import lxml
import geocoder

# %% [markdown]
# **Task 1:**
#
# *Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe*

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

#the dataframe for scraped data will be called 'codes'.
#The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood:

codes = pd.DataFrame(columns = ['PostalCode', 'Borough', 'Neighbourhood'])

#getting html as 'src'
src = get(url).text

#creating a soup from 'src':
soup = bs(src, 'lxml')

# %%
#getting the table with postal codes
table = soup.table

#getting the rows with data
rows = table.findAll('tr')

#getting the table's fields and putting them in the dataframe
i = 0

for row in rows[1:]:
    tds = row.findAll('td')
    row_data = [j.text.strip() for j in tds]
    codes.loc[i] = row_data
    i+=1

# %% [markdown]
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
codes = codes[codes['Borough'] != 'Not assigned'].reset_index(drop=True)

# %% [markdown]
# **Task citation:**
#
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.
#
# **Approach:**
# 1. Get a list of unique postal codes
# 2. For each unique postal code, walk through scraped data ('codes'), find and concatenate neighbourhoods with the code
# 3. Create a new dataframe with unique codes in 'PostalCode' column, corresponding boroughs and concatenated neighbourhoods in 'Neighbourhood' column.

# %%
#getting a list of unique postal codes:
postcodes = list(set(codes['PostalCode']))

print('postcodes quantity: ', len(postcodes))

#creating a new dataframe for codes without duplicates
codes_nodup = pd.DataFrame(columns = codes.columns)

#For each unique postal code, walk through scraped data ('codes'), find and concatenate neighbourhoods with the code:
for k in range(len(postcodes)):
    
    nbs = [] #creating a list for neighbourhoods sharing the same postcode
    borough = ''
    
    for i in range(codes.shape[0]):
        if postcodes[k]==codes.loc[i, 'PostalCode']:
            nbs.append(codes.loc[i, 'Neighbourhood'])
            borough = codes.loc[i, 'Borough']
            
    #converting the list of neighbourhoods to a string:

    nbs_str = nbs[0] 
    
    for nb in nbs[1:]:
        nbs_str = nbs_str+', '+nb
    #print('nb_str: ', nbs_str)
    
    #recording the resulting row in the new dataframe
    codes_nodup.loc[k] = [postcodes[k], borough, nbs_str]
    
#displaying the head of the resulting dataframe
codes_nodup.head()
# Out:
# postcodes quantity:  103
#   PostalCode           Borough                   Neighbourhood
# 0        M5L  Downtown Toronto  Commerce Court, Victoria Hotel
# 1        M2K        North York                 Bayview Village
# 2        M6S      West Toronto              Runnymede, Swansea
# 3        M1G       Scarborough                          Woburn
# 4        M6G  Downtown Toronto                        Christie

# %% [markdown]
# **Task citation:**
#
# *If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.*

# %%
#creating a new dataframe for the result
codes_res = codes_nodup

#replacing 'Not assigned' neighbourhoods with corresponding boroughs
for i in range(codes_res.shape[0]):
    if codes_res.loc[i, 'Neighbourhood'] == 'Not assigned':
        codes_res.loc[i, 'Neighbourhood'] = codes_res.loc[i, 'Borough']

# %% [markdown]
# **TASK ONE - ANSWER (Dataframe)**

# %%
#Here is the resulting dataframe
codes_res
# Out:
#     PostalCode           Borough  \
# 0          M5L  Downtown Toronto
# 1          M2K        North York
# 2          M6S      West Toronto
# 3          M1G       Scarborough
# 4          M6G  Downtown Toronto
# 5          M1X       Scarborough
# 6          M4E      East Toronto
# 7          M3L        North York
# 8          M2N        North York
# 9          M1T       Scarborough
# 10         M4Y  Downtown Toronto
# 11         M8Y         Etobicoke
# 12         M5P   Central Toronto
# 13         M6E              York
# 14         M5V  Downtown Toronto
# 15         M8Z         Etobicoke
# 16         M6B        North York
# 17         M5G  Downtown Toronto
# 18         M2H        North York
# 19         M4P   Central Toronto
# 20         M6R      West Toronto
# 21         M1V       Scarborough
# 22         M5H  Downtown Toronto
# 23         M6J      West Toronto
# 24         M3B        North York
# 25         M4S   Central Toronto
# 26         M5J  Downtown Toronto
# 27         M6N              York
# 28         M5S  Downtown Toronto
# 29         M1H       Scarborough
# ..         ...               ...
# 73         M1P       Scarborough
# 74         M5W  Downtown Toronto
# 75         M5M        North York
# 76         M8X         Etobicoke
# 77         M3A        North York
# 78         M1L       Scarborough
# 79         M8W         Etobicoke
# 80         M6H      West Toronto
# 81         M4N   Central Toronto
# 82         M4K      East Toronto
# 83         M1C       Scarborough
# 84         M6M              York
# 85         M1E       Scarborough
# 86         M9N              York
# 87         M5N   Central Toronto
# 88         M5K  Downtown Toronto
# 89         M1B       Scarborough
# 90         M3K        North York
# 91         M1J       Scarborough
# 92         M9C         Etobicoke
# 93         M2M        North York
# 94         M3N        North York
# 95         M3M        North York
# 96         M9M        North York
# 97         M4L      East Toronto
# 98         M4W  Downtown Toronto
# 99         M8V         Etobicoke
# 100        M4G         East York
# 101        M5X  Downtown Toronto
# 102        M6L        North York
#
#                                          Neighbourhood
# 0                       Commerce Court, Victoria Hotel
# 1                                      Bayview Village
# 2                                   Runnymede, Swansea
# 3                                               Woburn
# 4                                             Christie
# 5                                          Upper Rouge
# 6                                          The Beaches
# 7                                            Downsview
# 8                                           Willowdale
# 9              Clarks Corners, Tam O'Shanter, Sullivan
# 10                                Church and Wellesley
# 11   Old Mill South, King's Mill Park, Sunnylea, Hu...
# 12                            Forest Hill North & West
# 13                                 Caledonia-Fairbanks
# 14   CN Tower, King and Spadina, Railway Lands, Har...
# 15   Mimico NW, The Queensway West, South of Bloor,...
# 16                                           Glencairn
# 17                                  Central Bay Street
# 18                                   Hillcrest Village
# 19                                    Davisville North
# 20                              Parkdale, Roncesvalles
# 21   Milliken, Agincourt North, Steeles East, L'Amo...
# 22                            Richmond, Adelaide, King
# 23                            Little Portugal, Trinity
# 24                                           Don Mills
# 25                                          Davisville
# 26   Harbourfront East, Union Station, Toronto Islands
# 27                       Runnymede, The Junction North
# 28                      University of Toronto, Harbord
# 29                                           Cedarbrae
# ..                                                 ...
# 73   Dorset Park, Wexford Heights, Scarborough Town...
# 74                                      Stn A PO Boxes
# 75                   Bedford Park, Lawrence Manor East
# 76       The Kingsway, Montgomery Road, Old Mill North
# 77                                           Parkwoods
# 78                     Golden Mile, Clairlea, Oakridge
# 79                              Alderwood, Long Branch
# 80                        Dufferin, Dovercourt Village
# 81                                       Lawrence Park
# 82                        The Danforth West, Riverdale
# 83              Rouge Hill, Port Union, Highland Creek
# 84    Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 85                   Guildwood, Morningside, West Hill
# 86                                              Weston
# 87                                            Roselawn
# 88            Toronto Dominion Centre, Design Exchange
# 89                                      Malvern, Rouge
# 90                                           Downsview
# 91                                 Scarborough Village
# 92   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 93                             Willowdale, Newtonbrook
# 94                                           Downsview
# 95                                           Downsview
# 96                                    Humberlea, Emery
# 97                      India Bazaar, The Beaches West
# 98                                            Rosedale
# 99        New Toronto, Mimico South, Humber Bay Shores
# 100                                            Leaside
# 101             First Canadian Place, Underground city
# 102           North Park, Maple Leaf Park, Upwood Park
#
# [103 rows x 3 columns]

# %% [markdown]
# Task citation: *In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe*

# %% [markdown]
# **TASK ONE - ANSWER (Dataframe shape)**

# %%
codes_res.shape
# Out:
# (103, 3)

# %% [markdown]
# **END OF THE TASK ONE**

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **TASK TWO**
#
# **Task citation:**
#
#
# *Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.*

# %% [markdown]
# Let's try to get coordinates from Geocoder. If we can't, let's use the csv.

# %%
#creating a function for getting coordinates from Geocoder

def get_coordinates_from_geocoder(postal_code, try_limit = 3):
    # task citation: initialize your variable to None
    lat_lng_coords = None
    
    i = 0
    
    # task citation: loop until you get the coordinates
    # task comment: will loop only until we are within pre-defined loop number limit
    
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
        i+=1
        
        if i > try_limit: #exiting the loop when the max number of loops is exceeded
            break

    try:
        latitude = lat_lng_coords[0]
        longitude = lat_lng_coords[1]
        
    except:
        print('error getting coordinates from Geocoder for the code: ', postal_code)
        latitude = longitude = 'error'
    
    return (latitude, longitude)

# %% [markdown]
# Let's get the coordinates. If we can't get any coordinates from Geocoder 10 times, we switch to the csv.

# %%
if 'Latitude' not in codes_res.columns:
    codes_res['Latitude'] = None
    codes_res['Longitude'] = None
    

rows_to_request = codes_res[(codes_res['Latitude'].isnull()) | (codes_res['Longitude'].isnull())].index

try_count = 0
try_limit = 3

for row in rows_to_request:
    
    if try_count > try_limit:
        print('Stopping attempts to get coordinates from Geocoder.')
        use_csv = True
        break
    
    latlon = get_coordinates_from_geocoder(codes_res.loc[row, 'PostalCode'])
        
    if latlon[0] == 'error' or latlon[1] == 'error':
        
        print('error getting coordinates from Geocoder. Try count: ', try_count)
        try_count+=1

    else:
        codes_res.loc[row, 'Latitude'] = latlon[0]
        codes_res.loc[row, 'Longitude'] = latlon[1]
# Out:
# error getting coordinates from Geocoder for the code:  M5G
# error getting coordinates from Geocoder. Try count:  0
# error getting coordinates from Geocoder for the code:  M6J
# error getting coordinates from Geocoder. Try count:  1
# error getting coordinates from Geocoder for the code:  M3B
# error getting coordinates from Geocoder. Try count:  2
# error getting coordinates from Geocoder for the code:  M4S
# error getting coordinates from Geocoder. Try count:  3
# Stopping attempts to get coordinates from Geocoder.

# %%
if use_csv:
    backup_csv = pd.read_csv('Geospatial_Coordinates.csv', encoding='cp1252')
    codes_res = codes_res.drop(['Latitude', 'Longitude'],axis = 1)
    codes_res = codes_res.join(backup_csv.set_index('Postal Code'), on = 'PostalCode')

# %%
codes_res
# Out:
#     PostalCode           Borough  \
# 0          M5L  Downtown Toronto
# 1          M2K        North York
# 2          M6S      West Toronto
# 3          M1G       Scarborough
# 4          M6G  Downtown Toronto
# 5          M1X       Scarborough
# 6          M4E      East Toronto
# 7          M3L        North York
# 8          M2N        North York
# 9          M1T       Scarborough
# 10         M4Y  Downtown Toronto
# 11         M8Y         Etobicoke
# 12         M5P   Central Toronto
# 13         M6E              York
# 14         M5V  Downtown Toronto
# 15         M8Z         Etobicoke
# 16         M6B        North York
# 17         M5G  Downtown Toronto
# 18         M2H        North York
# 19         M4P   Central Toronto
# 20         M6R      West Toronto
# 21         M1V       Scarborough
# 22         M5H  Downtown Toronto
# 23         M6J      West Toronto
# 24         M3B        North York
# 25         M4S   Central Toronto
# 26         M5J  Downtown Toronto
# 27         M6N              York
# 28         M5S  Downtown Toronto
# 29         M1H       Scarborough
# ..         ...               ...
# 73         M1P       Scarborough
# 74         M5W  Downtown Toronto
# 75         M5M        North York
# 76         M8X         Etobicoke
# 77         M3A        North York
# 78         M1L       Scarborough
# 79         M8W         Etobicoke
# 80         M6H      West Toronto
# 81         M4N   Central Toronto
# 82         M4K      East Toronto
# 83         M1C       Scarborough
# 84         M6M              York
# 85         M1E       Scarborough
# 86         M9N              York
# 87         M5N   Central Toronto
# 88         M5K  Downtown Toronto
# 89         M1B       Scarborough
# 90         M3K        North York
# 91         M1J       Scarborough
# 92         M9C         Etobicoke
# 93         M2M        North York
# 94         M3N        North York
# 95         M3M        North York
# 96         M9M        North York
# 97         M4L      East Toronto
# 98         M4W  Downtown Toronto
# 99         M8V         Etobicoke
# 100        M4G         East York
# 101        M5X  Downtown Toronto
# 102        M6L        North York
#
#                                          Neighbourhood   Latitude  Longitude
# 0                       Commerce Court, Victoria Hotel  43.648198 -79.379817
# 1                                      Bayview Village  43.786947 -79.385975
# 2                                   Runnymede, Swansea  43.651571 -79.484450
# 3                                               Woburn  43.770992 -79.216917
# 4                                             Christie  43.669542 -79.422564
# 5                                          Upper Rouge  43.836125 -79.205636
# 6                                          The Beaches  43.676357 -79.293031
# 7                                            Downsview  43.739015 -79.506944
# 8                                           Willowdale  43.770120 -79.408493
# 9              Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 10                                Church and Wellesley  43.665860 -79.383160
# 11   Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 12                            Forest Hill North & West  43.696948 -79.411307
# 13                                 Caledonia-Fairbanks  43.689026 -79.453512
# 14   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 15   Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
# 16                                           Glencairn  43.709577 -79.445073
# 17                                  Central Bay Street  43.657952 -79.387383
# 18                                   Hillcrest Village  43.803762 -79.363452
# 19                                    Davisville North  43.712751 -79.390197
# 20                              Parkdale, Roncesvalles  43.648960 -79.456325
# 21   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 22                            Richmond, Adelaide, King  43.650571 -79.384568
# 23                            Little Portugal, Trinity  43.647927 -79.419750
# 24                                           Don Mills  43.745906 -79.352188
# 25                                          Davisville  43.704324 -79.388790
# 26   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 27                       Runnymede, The Junction North  43.673185 -79.487262
# 28                      University of Toronto, Harbord  43.662696 -79.400049
# 29                                           Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 73   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 74                                      Stn A PO Boxes  43.646435 -79.374846
# 75                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 76       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 77                                           Parkwoods  43.753259 -79.329656
# 78                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 79                              Alderwood, Long Branch  43.602414 -79.543484
# 80                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 81                                       Lawrence Park  43.728020 -79.388790
# 82                        The Danforth West, Riverdale  43.679557 -79.352188
# 83              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 84    Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 85                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 86                                              Weston  43.706876 -79.518188
# 87                                            Roselawn  43.711695 -79.416936
# 88            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 89                                      Malvern, Rouge  43.806686 -79.194353
# 90                                           Downsview  43.737473 -79.464763
# 91                                 Scarborough Village  43.744734 -79.239476
# 92   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 93                             Willowdale, Newtonbrook  43.789053 -79.408493
# 94                                           Downsview  43.761631 -79.520999
# 95                                           Downsview  43.728496 -79.495697
# 96                                    Humberlea, Emery  43.724766 -79.532242
# 97                      India Bazaar, The Beaches West  43.668999 -79.315572
# 98                                            Rosedale  43.679563 -79.377529
# 99        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 100                                            Leaside  43.709060 -79.363452
# 101             First Canadian Place, Underground city  43.648429 -79.382280
# 102           North Park, Maple Leaf Park, Upwood Park  43.713756 -79.490074
#
# [103 rows x 5 columns]

# %%
codes_res.shape
# Out:
# (103, 5)

# %%
codes_res.to_csv('codes_res.csv', index=None)

# %% [markdown]
# **END OF TASK TWO**

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------
